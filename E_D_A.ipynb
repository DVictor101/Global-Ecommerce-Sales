# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %%
cleaned_data = pd.read_csv("./data_folder/cleaned_data.csv")

# %%
cleaned_data.head(2)
# Out:
#    Order_Date  Year    Month Quarter  Season Customer_Gender Customer_Segment  \
# 0  2021-01-05  2021  January      Q1  Winter          Female              New
# 1  2021-01-15  2021  January      Q1  Winter          Female          Premium
#
#         Region Country     Category  ... Discount Revenue    Cost  Profit  \
# 0         Asia   India     Clothing  ...      0.4  112.19  130.29  -18.10
# 1  Middle East  Jordan  Electronics  ...      0.5  931.58  870.47   61.11
#
#    Profit_Margin_%  Shipping_Cost  Shipping_Method  Shipping_Days  \
# 0           -16.13          18.27         Standard             22
# 1             6.56          37.13          Express             18
#
#      Payment_Method  Order_Status
# 0  Cash on Delivery     Delivered
# 1       Credit Card     Delivered
#
# [2 rows x 24 columns]

# %% [markdown]
# ## reviewing our cleaned data

# %%
cleaned_data.describe()
# Out:
#                Year    Unit_Price      Quantity     Discount       Revenue  \
# count  10000.000000  10000.000000  10000.000000  10000.00000  10000.000000
# mean    2022.756300    236.307452      2.731300      0.17675    528.438770
# std        0.878628    380.901351      2.038508      0.16167   1154.811538
# min     2021.000000     10.010000      1.000000      0.00000      5.330000
# 25%     2022.000000     42.767500      1.000000      0.00000     67.227500
# 50%     2023.000000     92.495000      2.000000      0.15000    164.600000
# 75%     2023.000000    221.822500      4.000000      0.30000    469.952500
# max     2024.000000   2497.760000     10.000000      0.50000  19966.500000
#
#                Cost        Profit  Profit_Margin_%  Shipping_Cost  \
# count  10000.000000  10000.000000     10000.000000   10000.000000
# mean     384.674939    143.763831        23.648594      32.299889
# std      828.069100    420.487992        21.496639      28.424003
# ...

# %%
cleaned_data.shape
# Out:
# (10000, 24)

# %%
cleaned_data["Revenue"].sum()
# Out:
# np.float64(5284387.7)

# %%
cleaned_data["Profit"].sum()
# Out:
# np.float64(1437638.31)

# %% [markdown]
# # finding out which country generated the highest revenue

# %%
country_revenue = cleaned_data.groupby("Country")["Revenue"].sum().sort_values(ascending=False)

highest_country_revenue
# Out:
# Country
# Canada          454911.29
# USA             444541.88
# Mexico          431676.58
# Egypt           344299.35
# Jordan          297916.85
# China           295780.41
# Japan           288011.04
# Italy           279837.36
# India           271854.16
# France          263944.47
# UK              250862.62
# Kuwait          245041.85
# Spain           242483.27
# South Korea     238989.94
# Saudi Arabia    238001.02
# Germany         237529.83
# Singapore       235371.63
# UAE             223334.15
# Name: Revenue, dtype: float64

# %%
# visualization of the highest country revenue

country_revenue.plot(kind="bar", figsize = (10,5))

plt.title("Countries by Revenue")
plt.xlabel("Countries")
plt.ylabel("Revenue")
plt.show()

# %% [markdown]
# ** NOTE ** : CANADA generated the highest revenue

# %% [markdown]
# # countries Revenue by region

# %%
region_by_revenue = cleaned_data.groupby("Region")["Revenue"].sum().sort_values(ascending=False)

region_by_revenue
# Out:
# Region
# Middle East      1348593.22
# North America    1331129.75
# Asia             1330007.18
# Europe           1274657.55
# Name: Revenue, dtype: float64

# %%
region_by_revenue.plot(kind="bar", figsize = (10,5))

plt.xlabel("Region")
plt.ylabel("Revenue")
plt.show()

# %% [markdown]
# **Note: Middle east has the highest revenue **

# %%
cleaned_data.head(2)
# Out:
#    Order_Date  Year    Month Quarter  Season Customer_Gender Customer_Segment  \
# 0  2021-01-05  2021  January      Q1  Winter          Female              New
# 1  2021-01-15  2021  January      Q1  Winter          Female          Premium
#
#         Region Country     Category  ... Discount Revenue    Cost  Profit  \
# 0         Asia   India     Clothing  ...      0.4  112.19  130.29  -18.10
# 1  Middle East  Jordan  Electronics  ...      0.5  931.58  870.47   61.11
#
#    Profit_Margin_%  Shipping_Cost  Shipping_Method  Shipping_Days  \
# 0           -16.13          18.27         Standard             22
# 1             6.56          37.13          Express             18
#
#      Payment_Method  Order_Status
# 0  Cash on Delivery     Delivered
# 1       Credit Card     Delivered
#
# [2 rows x 24 columns]

# %%
# revenue by year

revenue_by_year = cleaned_data.groupby("Year")["Revenue"].sum()
revenue_by_year
# Out:
# Year
# 2021     506060.36
# 2022    1321845.01
# 2023    2308640.02
# 2024    1147842.31
# Name: Revenue, dtype: float64

# %%
revenue_by_year.plot(kind="bar", figsize = (10, 5))

plt.xlabel("Year")
plt.ylabel("Revenue")
plt.show()

# %% [markdown]
# ** Note: the year 2023 has the highest revenue **

# %%
# Revenue by month

revenue_by_month = cleaned_data.groupby("Month")["Revenue"].sum().sort_values(ascending=False)
revenue_by_month
# Out:
# Month
# October      501270.79
# March        486445.31
# January      485925.07
# August       480071.07
# May          448767.01
# April        446457.73
# November     434206.11
# September    423516.14
# July         411466.54
# December     410581.11
# June         399308.50
# February     356372.32
# Name: Revenue, dtype: float64

# %%
revenue_by_month.plot(kind="bar", figsize = (10, 5))

plt.xlabel("Month")
plt.ylabel("Revenue")
plt.show()

# %% [markdown]
# ** Note: October is the month with the highest revenue

# %%
## showing year and region revenue


year_region_revenue = cleaned_data.groupby(["Region", "Year"])["Revenue"].sum().sort_values(ascending = False)

year_region_revenue.plot(kind="bar", figsize=(10, 5));
plt.ylabel = ("Revenue");
plt.xlabel = ("Region");

# %%
## showing year and region revenue


year_region_revenue = cleaned_data.groupby(["Region", "Year"])["Revenue"].sum().unstack()

year_region_revenue.plot(kind="bar", figsize=(10, 5));
plt.ylabel = ("Revenue");
plt.xlabel = ("Region");

# %% [markdown]
# ## Profit Exploratory Analysis

# %%
country_profit = cleaned_data.groupby("Country")["Profit"].sum().sort_values(ascending = False)
country_profit
# Out:
# Country
# USA             123170.72
# Mexico          122543.90
# Canada          121002.80
# Egypt           103930.99
# Jordan           85073.63
# India            79751.95
# France           78543.11
# Italy            77982.55
# Japan            74848.58
# China            73762.21
# Kuwait           71643.56
# Saudi Arabia     66937.98
# Singapore        65263.04
# Spain            61976.48
# UK               59212.52
# Germany          58269.90
# UAE              56936.69
# South Korea      56787.70
# Name: Profit, dtype: float64

# %%
country_profit.plot(kind = "pie");

# %%
country_profit.plot(kind = "bar", figsize=(10, 5));

plt.xlabel("Profit")
plt.ylabel("Country")
plt.show();

# %% [markdown]
# ** Note: USA is the country with the highest profit ***

# %%
region_profit = cleaned_data.groupby("Region")["Profit"].sum().sort_values(ascending = False)
region_profit
# Out:
# Region
# Middle East      384522.85
# North America    366717.42
# Asia             350413.48
# Europe           335984.56
# Name: Profit, dtype: float64

# %%
region_profit.plot(kind = "bar", figsize=(10, 5));

plt.xlabel("Profit")
plt.ylabel("Country")
plt.show();

# %% [markdown]
# *** Middle east is the region with the highest profit***

# %% [markdown]
# ## Product exploratory Analysis

# %%
def profit_analysis(x, y):
    result = cleaned_data.groupby(x)[y].sum().sort_values(ascending=False)
    return result

product_quantity = profit_analysis("Sub_Category", "Quantity")
product_quantity
# Out:
# Sub_Category
# Skincare         2967
# Software         2848
# Books            2819
# Supplements      2482
# Appliances       1945
# Women's Wear     1862
# Furniture        1796
# Kitchen Tools    1794
# Men's Wear       1783
# Footwear         1730
# Smartphones      1398
# Laptops          1326
# Tablets          1302
# Headphones       1261
# Name: Quantity, dtype: int64

# %%
product_quantity.plot(kind = "bar", figsize = (10,5))

plt.xlabel= ("SubCategory")
plt.ylabel= ("Quantity")
plt.show();

# %% [markdown]
# ** Note: Skin care product is the product with the highest quantity purchased ***

# %%
cleaned_data.head(3)
# Out:
#    Order_Date  Year    Month Quarter  Season Customer_Gender Customer_Segment  \
# 0  2021-01-05  2021  January      Q1  Winter          Female              New
# 1  2021-01-15  2021  January      Q1  Winter          Female          Premium
# 2  2021-01-20  2021  January      Q1  Winter          Female          Regular
#
#         Region Country     Category  ... Discount  Revenue     Cost   Profit  \
# 0         Asia   India     Clothing  ...      0.4   112.19   130.29   -18.10
# 1  Middle East  Jordan  Electronics  ...      0.5   931.58   870.47    61.11
# 2  Middle East   Egypt  Electronics  ...      0.1  7528.32  3884.40  3643.92
#
#    Profit_Margin_%  Shipping_Cost  Shipping_Method  Shipping_Days  \
# 0           -16.13          18.27         Standard             22
# 1             6.56          37.13          Express             18
# 2            48.40           8.60         Standard             17
#
#      Payment_Method  Order_Status
# 0  Cash on Delivery     Delivered
# ...

# %%
cleaned_data.columns
# Out:
# Index(['Order_Date', 'Year', 'Month', 'Quarter', 'Season', 'Customer_Gender',
#        'Customer_Segment', 'Region', 'Country', 'Category', 'Sub_Category',
#        'Product_Name', 'Unit_Price', 'Quantity', 'Discount', 'Revenue', 'Cost',
#        'Profit', 'Profit_Margin_%', 'Shipping_Cost', 'Shipping_Method',
#        'Shipping_Days', 'Payment_Method', 'Order_Status'],
#       dtype='object')

# %%
## product name in skin care that has the the highest amount of purchase


skindata_product = cleaned_data[cleaned_data["Sub_Category"] == "Skincare"].groupby("Product_Name")["Quantity"].sum().sort_values(ascending = False)
skindata_product
# Out:
# Product_Name
# Vitamin C Serum        662
# Sunscreen SPF50        636
# Moisturizing Cream     590
# Retinol Night Cream    570
# Hyaluronic Acid        509
# Name: Quantity, dtype: int64

# %%
skindata_product.plot(kind = "bar", figsize = (10,5))

plt.xlabel= ("SubCategory")
plt.ylabel= ("Quantity")
plt.show();

# %% [markdown]
# ** Vitamin C Serum is the skin care product with the highest quantity"""

# %%
## most profitable product

profitable_product = profit_analysis("Product_Name", "Profit")
profitable_product
# Out:
# Product_Name
# Lenovo ThinkPad X1         100584.09
# MacBook Air M2              97941.48
# Dell XPS 15                 89052.11
# HP Spectre x360             89029.69
# ASUS ZenBook                70166.24
#                              ...
# Atomic Habits                3403.63
# Rich Dad Poor Dad            3049.67
# Deep Work                    3015.08
# The Psychology of Money      2951.70
# Thinking Fast and Slow       2772.83
# Name: Profit, Length: 70, dtype: float64

# %% [markdown]
# *** Note: Lenovo ThinkPad X1 is the modst profitable product ***

# %%
## ploting the most profitable category


profitable_sub_category = profit_analysis("Sub_Category", "Profit")
profitable_sub_category.plot(kind="bar", figsize=(10,5))


plt.ylabel = ("Profit")
plt.show();

# %% [markdown]
# ## correlations

# %%
## corerelation between revenue and profit

cleaned_data[["Revenue", "Profit"]].corr()
# Out:
#           Revenue    Profit
# Revenue  1.000000  0.849184
# Profit   0.849184  1.000000

# %% [markdown]
# ## Exploratory Analysis Results
# 1) CANADA generated the highest revenue.
# 2) The Middle East has the highest revenue.
# 3) The year 2023 has the highest revenue
# 4) October is the month with the highest revenue
# 5) North America in the year 2023 has the highest revenue
# 6) The USA is the country with the highest profit
# 7) The Middle East is the region with the highest profit
# 8) Skin care products are the product with the highest quantity purchased
# 9) Vitamin C Serum is the skin care product with the highest quantity
# 10) Laptops are the most profitable product
# 11) Lenovo ThinkPad X1 is the most profitable product
