# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline 

from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from xgboost import XGBRegressor

from sklearn.metrics import(mean_absolute_error,
    mean_squared_error,
    r2_score)

# %%
## import featured dat
data = pd.read_csv("../data_folder/feature_engineerd_data.csv")

# %%
##viewing top two rows
data.head(2)
# Out:
#    Unnamed: 0  Order_Date  Season Country       Category Sub_Category  \
# 0           0  2023-01-18  Winter  Mexico    Electronics  Smartphones
# 1           1  2023-11-13    Fall     USA  Books & Media        Books
#
#              Product_Name  Unit_Price  Quantity  Discount  ...  \
# 0               Xiaomi 13      520.40         7      0.00  ...
# 1  Thinking Fast and Slow       22.59         2      0.25  ...
#
#    Profit_Margin_%  Shipping_Cost  Shipping_Days  Payment_Method  \
# 0            32.91           2.25              4      Google Pay
# 1            16.41           4.72              5     Credit Card
#
#                            Month                           Year  \
# 0  1970-01-01 00:00:00.000000001  1970-01-01 00:00:00.000002023
# 1  1970-01-01 00:00:00.000000011  1970-01-01 00:00:00.000002023
#
#   revenue_per_unit profit_per_unit scost_per_revenue  net_revenue
# 0           520.40      171.241429          0.000618  1619.022222
# 1            16.94        2.780000          0.139315     7.177966
#
# [2 rows x 23 columns]

# %%
# Our target variable is profit

y = data["Profit"]

# %%
#viewing the column features we have
data.columns
# Out:
# Index(['Unnamed: 0', 'Order_Date', 'Season', 'Country', 'Category',
#        'Sub_Category', 'Product_Name', 'Unit_Price', 'Quantity', 'Discount',
#        'Revenue', 'Cost', 'Profit', 'Profit_Margin_%', 'Shipping_Cost',
#        'Shipping_Days', 'Payment_Method', 'Month', 'Year', 'revenue_per_unit',
#        'profit_per_unit', 'scost_per_revenue', 'net_revenue'],
#       dtype='object')

# %%
## dropping columns that directly reveal profit

data = data.drop(columns = ["Month", "Order_Date", "Revenue", "Cost", "net_revenue","Year","scost_per_revenue", "revenue_per_unit", "profit_per_unit", "Profit_Margin_%" ])

# %%
## viewing column to confirm removal
data.head(2)
# Out:
#    Unnamed: 0  Season Country       Category Sub_Category  \
# 0           0  Winter  Mexico    Electronics  Smartphones
# 1           1    Fall     USA  Books & Media        Books
#
#              Product_Name  Unit_Price  Quantity  Discount   Profit  \
# 0               Xiaomi 13      520.40         7      0.00  1198.69
# 1  Thinking Fast and Slow       22.59         2      0.25     5.56
#
#    Shipping_Cost  Shipping_Days Payment_Method
# 0           2.25              4     Google Pay
# 1           4.72              5    Credit Card

# %%
# checking the data shape:  1000 rows and 13 columns
data.shape
# Out:
# (10000, 13)

# %%
## assigning our x data to be used for x_train and x_test
x = data[ [
        "Season",
        "Country",
        "Category",
        "Sub_Category",
        "Product_Name",
        "Unit_Price",
        "Quantity",
        "Discount",
        "Shipping_Cost",
        "Shipping_Days",
        "Payment_Method"
    ]]

# %%
## Identifying numerical and categorical columns

numerical_columns = x.select_dtypes(include=["int64", "float64"]).columns

categorical_columns = x.select_dtypes(include=["object"]).columns

# %%
#list of numerical columns
numerical_columns
# Out:
# Index(['Unit_Price', 'Quantity', 'Discount', 'Shipping_Cost', 'Shipping_Days'], dtype='object')

# %%
#list of categirical column

categorical_columns
# Out:
# Index(['Season', 'Country', 'Category', 'Sub_Category', 'Product_Name',
#        'Payment_Method'],
#       dtype='object')

# %%
## Encoding categorical data

preprocessor = ColumnTransformer(
    transformers=[
        (
            "cat",
            OneHotEncoder(handle_unknown = "ignore"),
            categorical_columns
        )
    ],
    remainder="passthrough"
)

# %%
## splitting the data

x_train, x_test, y_train, y_test =train_test_split(
    x,
    y,
    test_size = 0.2,
    random_state = 34
)

# %%
## Training using MODEL 1(Linear regression)


First_pipeline = Pipeline([
    ("preprocessor", preprocessor),
("model", LinearRegression())])

# %%
First_pipeline.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   Index(['Season', 'Country', 'Category', 'Sub_Category', 'Product_Name',
#        'Payment_Method'],
#       dtype='object'))])),
#                 ('model', LinearRegression())])

# %%
#checking predictions

first_pred = First_pipeline.predict(x_test)

# %%
first_pred
# Out:
# array([-74.72113941, 295.40119484, -45.46911584, ..., -37.64060985,
#        684.53856491,  89.98667781], shape=(2000,))

# %%
## Evaluation

MAE = mean_absolute_error(y_test, first_pred)
MAE
# Out:
# 141.2756424523951

# %%
MSE = np.sqrt(mean_squared_error(y_test, first_pred))
MSE
# Out:
# np.float64(302.5810078106694)

# %%
R2 = r2_score(y_test, first_pred)
R2
# Out:
# 0.43707798291734257

# %%
## Model 2(Randomforestregressor)



rf_pipeline = Pipeline([
    ("preprocessor", preprocessor),
    ("model", RandomForestRegressor(
        n_estimators=20,
        random_state = 34
    ))
])

# %%
#fitting our model randomforestregressor

rf_pipeline.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   Index(['Season', 'Country', 'Category', 'Sub_Category', 'Product_Name',
#        'Payment_Method'],
#       dtype='object'))])),
#                 ('model',
#                  RandomForestRegressor(n_estimators=20, random_state=34))])

# %%
rf_pred = rf_pipeline.predict(x_test)
rf_pred
# Out:
# array([  64.4115,  352.5145,    5.102 , ...,  -16.656 , 1061.9665,
#          19.388 ], shape=(2000,))

# %%
## evaluate


rf_MAE = mean_absolute_error(y_test, rf_pred)
print(rf_MAE)
rf_R2 = r2_score(y_test, rf_pred)
print(rf_R2)
rf_MSE = np.sqrt(mean_squared_error(y_test, rf_pred))
print(rf_MSE)
# Out:
# 54.051301
# 0.836847705045906
# 162.89739565325237

# %%
## Model 3(Gradient Boosting)


gbpipeline = Pipeline([
    ("Preprocessor", preprocessor),
    ("model", GradientBoostingRegressor(
        random_state = 34
    ))

])

# %%
gbpipeline.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('Preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   Index(['Season', 'Country', 'Category', 'Sub_Category', 'Product_Name',
#        'Payment_Method'],
#       dtype='object'))])),
#                 ('model', GradientBoostingRegressor(random_state=34))])

# %%
gb_pred = gbpipeline.predict(x_test)
gb_pred
# Out:
# array([ -11.81433327,  323.13177692,    7.15991211, ...,  -45.21024006,
#        1076.16344906,   -1.34769767], shape=(2000,))

# %%
## evaluate


gb_MAE = mean_absolute_error(y_test, gb_pred)
print(gb_MAE)
gb_R2 = r2_score(y_test, gb_pred)
print(gb_R2)
gb_MSE = np.sqrt(mean_squared_error(y_test, gb_pred))
print(gb_MSE)
# Out:
# 61.68679573631301
# 0.8453293097971871
# 158.6067109648302

# %%
## Model 4(XGBRegressor)


xgbpipeline = Pipeline([
    ("Preprocessor", preprocessor),
    ("model", XGBRegressor(
        objective='reg:squarederror',
        n_estimators=100, random_state=34
    ))

])

# %%
xgbpipeline.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('Preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   Index(['Season', 'Country', 'Category', 'Sub_Category', 'Product_Name',
#        'Payment_Method'],
#       dtype='object'))])),
#                 ('model',
#                  XGBRegressor(base_score=None, booster=None, callbacks=None,
#                               colsample_bylevel=None, colsample_bynode=None,...
#                               feature_types=None, feature_weights=None,
#                               gamma=None, grow_policy=None,
#                               importance_type=None,
#                               interaction_constraints=None, learning_rate=None,
#                               max_bin=None, max_cat_threshold=None,
#                               max_cat_to_onehot=None, max_delta_step=None,
#                               max_depth=None, max_leaves=None,
#                               min_child_weight=None, missing=nan,
#                               monotone_constraints=None, multi_strategy=None,
#                               n_estimators=100, n_jobs=None,
#                               num_parallel_tree=None, ...))])

# %%
xgb_pred = gbpipeline.predict(x_test)
xgb_pred
# Out:
# array([ -11.81433327,  323.13177692,    7.15991211, ...,  -45.21024006,
#        1076.16344906,   -1.34769767], shape=(2000,))

# %%
## evaluate


xgb_MAE = mean_absolute_error(y_test, xgb_pred)
print(xgb_MAE)
xgb_R2 = r2_score(y_test, xgb_pred)
print(xgb_R2)
xgb_RMSE = np.sqrt(mean_squared_error(y_test, xgb_pred))
print(xgb_RMSE)
# Out:
# 61.68679573631301
# 0.8453293097971871
# 158.6067109648302

# %%
## Model 5(DecisionTreeRegressor)


despipeline = Pipeline([
    ("Preprocessor", preprocessor),
    ("model", DecisionTreeRegressor(
    ))

])

# %%
despipeline.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('Preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   Index(['Season', 'Country', 'Category', 'Sub_Category', 'Product_Name',
#        'Payment_Method'],
#       dtype='object'))])),
#                 ('model', DecisionTreeRegressor())])

# %%
des_pred = despipeline.predict(x_test)
des_pred
# Out:
# array([ 66.52, 324.05,   5.92, ..., -43.08, 786.02,  21.76], shape=(2000,))

# %% [markdown]
# ** Linear Regression did better**

# %%
## evaluate


des_MAE = mean_absolute_error(y_test, des_pred)
print(des_MAE)
des_R2 = r2_score(y_test, des_pred)
print(des_R2)
des_MSE = np.sqrt(mean_squared_error(y_test, des_pred))
print(des_MSE)
# Out:
# 76.41108
# 0.6140943340945435
# 250.52906925584503

# %%
# MAE,MSE,R2, rf_MAE,rf_MSE,rf_R2, gb_MAE,gb_MSE,gb_R2,

compare_model = pd.DataFrame([[MAE,MSE,R2], [rf_MAE,rf_MSE,rf_R2],[ gb_MAE,gb_MSE,gb_R2],[xgb_MAE, xgb_RMSE, xgb_R2],[des_MAE, des_MSE, des_R2]],
                            index=["Linear Regression", "RandomForest Regressor", "Gradient Boosting", "XGBRegressor", "DecisionTreeRegressor" ],
                            columns= ["MAE", "MSE", "R2"])
compare_model
# Out:
#                                MAE         MSE        R2
# Linear Regression       141.275642  302.581008  0.437078
# RandomForest Regressor   54.051301  162.897396  0.836848
# Gradient Boosting        61.686796  158.606711  0.845329
# XGBRegressor             61.686796  158.606711  0.845329
# DecisionTreeRegressor    76.411080  250.529069  0.614094

# %%
x.columns
# Out:
# Index(['Season', 'Country', 'Category', 'Sub_Category', 'Product_Name',
#        'Unit_Price', 'Quantity', 'Discount', 'Shipping_Cost', 'Shipping_Days',
#        'Payment_Method'],
#       dtype='object')

# %%
## performing hyperparameter tuning for xgboost

param_grid = {
    "model__n_estimators": [100, 200, 300],
    'model__max_depth': [3, 6, 9],
    'model__learning_rate': [0.01, 0.1, 0.2],
    'model__subsample': [0.8, 1.0],
    'model__colsample_bytree': [0.8, 1.0]
}


grid_search = GridSearchCV(
    estimator=xgbpipeline, param_grid=param_grid, cv=3, n_jobs=-1, verbose=1)
grid_search.fit(x_train, y_train)

print("Best parameters:", grid_search.best_params_)
# Out:
# Fitting 3 folds for each of 108 candidates, totalling 324 fits
# Best parameters: {'model__colsample_bytree': 1.0, 'model__learning_rate': 0.1, 'model__max_depth': 6, 'model__n_estimators': 100, 'model__subsample': 1.0}

# %%
best_xgb = grid_search.best_estimator_

best_xgb_pred = best_xgb.predict(x_test)

best_xgb_mae = mean_absolute_error(y_test, best_xgb_pred)
best_xgb_rmse = np.sqrt(mean_squared_error(y_test, best_xgb_pred))
best_xgb_r2 = r2_score(y_test, best_xgb_pred)

print("MAE :", best_xgb_mae)
print("RMSE:", best_xgb_rmse)
print("R²  :", best_xgb_r2)
# Out:
# MAE : 54.190859741994444
# RMSE: 155.80455486181606
# R²  : 0.8507462660657306

# %%
xgb_param_grid = {
    "model__n_estimators": [100, 200, 300, 500],
    "model__learning_rate": [0.01, 0.05, 0.1, 0.2],
    "model__max_depth": [3, 5, 6, 8, 10],
    "model__min_child_weight": [1, 3, 5],
    "model__subsample": [0.6, 0.8, 1.0],
    "model__colsample_bytree": [0.6, 0.8, 1.0],
    "model__gamma": [0, 0.1, 0.3, 0.5],
    "model__reg_alpha": [0, 0.1, 1],
    "model__reg_lambda": [1, 2, 5]
}

# %%
xgb_random = RandomizedSearchCV(
    estimator=xgbpipeline,
    param_distributions=xgb_param_grid,
    n_iter=50,          # Try 50 random combinations
    scoring="r2",
    cv=5,
    verbose=2,
    random_state=42,
    n_jobs=-1
)

xgb_random.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# RandomizedSearchCV(cv=5,
#                    estimator=Pipeline(steps=[('Preprocessor',
#                                               ColumnTransformer(remainder='passthrough',
#                                                                 transformers=[('cat',
#                                                                                OneHotEncoder(handle_unknown='ignore'),
#                                                                                Index(['Season', 'Country', 'Category', 'Sub_Category', 'Product_Name',
#        'Payment_Method'],
#       dtype='object'))])),
#                                              ('model',
#                                               XGBRegressor(base_score=None,
#                                                            booster=None,
#                                                            callbacks=None,
#                                                            colsample_b...
#                    param_distributions={'model__colsample_bytree': [0.6, 0.8,
#                                                                     1.0],
#                                         'model__gamma': [0, 0.1, 0.3, 0.5],
#                                         'model__learning_rate': [0.01, 0.05,
#                                                                  0.1, 0.2],
#                                         'model__max_depth': [3, 5, 6, 8, 10],
#                                         'model__min_child_weight': [1, 3, 5],
#                                         'model__n_estimators': [100, 200, 300,
#                                                                 500],
#                                         'model__reg_alpha': [0, 0.1, 1],
#                                         'model__reg_lambda': [1, 2, 5],
#                                         'model__subsample': [0.6, 0.8, 1.0]},
#                    random_state=42, scoring='r2', verbose=2)

# %%
print("Best Parameters:")
print(xgb_random.best_params_)

print("\nBest Cross-Validation R²:")
print(xgb_random.best_score_)
# Out:
# Best Parameters:
# {'model__subsample': 1.0, 'model__reg_lambda': 2, 'model__reg_alpha': 0, 'model__n_estimators': 300, 'model__min_child_weight': 1, 'model__max_depth': 5, 'model__learning_rate': 0.05, 'model__gamma': 0.3, 'model__colsample_bytree': 1.0}
#
# Best Cross-Validation R²:
# 0.8809942371665841

# %%
## tuning gradient boosting


gb_param_grid = {
    "model__n_estimators": [100, 200, 300, 500],
    "model__learning_rate": [0.01, 0.05, 0.1, 0.2],
    "model__max_depth": [2, 3, 4, 5],
    "model__min_samples_split": [2, 5, 10],
    "model__min_samples_leaf": [1, 2, 4],
    "model__subsample": [0.8, 1.0],
    "model__max_features": ["sqrt", "log2", None]
}

# %%
gb_random = RandomizedSearchCV(
    estimator=gbpipeline,
    param_distributions=gb_param_grid,
    n_iter=50,
    scoring="r2",
    cv=5,
    random_state=42,
    verbose=2,
    n_jobs=-1
)

gb_random.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# RandomizedSearchCV(cv=5,
#                    estimator=Pipeline(steps=[('Preprocessor',
#                                               ColumnTransformer(remainder='passthrough',
#                                                                 transformers=[('cat',
#                                                                                OneHotEncoder(handle_unknown='ignore'),
#                                                                                Index(['Season', 'Country', 'Category', 'Sub_Category', 'Product_Name',
#        'Payment_Method'],
#       dtype='object'))])),
#                                              ('model',
#                                               GradientBoostingRegressor(random_state=34))]),
#                    n_iter=50, n_jobs=-1,
#                    param_distributions={'model__learning_rate': [0.01, 0.05,
#                                                                  0.1, 0.2],
#                                         'model__max_depth': [2, 3, 4, 5],
#                                         'model__max_features': ['sqrt', 'log2',
#                                                                 None],
#                                         'model__min_samples_leaf': [1, 2, 4],
#                                         'model__min_samples_split': [2, 5, 10],
#                                         'model__n_estimators': [100, 200, 300,
#                                                                 500],
#                                         'model__subsample': [0.8, 1.0]},
#                    random_state=42, scoring='r2', verbose=2)

# %%
print("Best Parameters:")
print(gb_random.best_params_)

print("\nBest Cross-Validation R²:")
print(gb_random.best_score_)
# Out:
# Best Parameters:
# {'model__subsample': 0.8, 'model__n_estimators': 300, 'model__min_samples_split': 2, 'model__min_samples_leaf': 1, 'model__max_features': None, 'model__max_depth': 5, 'model__learning_rate': 0.05}
#
# Best Cross-Validation R²:
# 0.8754521665324443

# %%
## Tuning random forest regressor hyperparameters to impeove on its default settings

from sklearn.ensemble import RandomForestRegressor

param_grid = {
    'model__n_estimators': [50],
    'model__max_depth': [20],
    'model__min_samples_split': [5],
    'model__min_samples_leaf': [1, 2]
}

random_search = RandomizedSearchCV(
    estimator = rf_pipeline,
    param_distributions = param_grid,
    n_iter = 30,
    cv=5,
    scoring='r2',
    random_state = 34,
    n_jobs=-1
)

random_search.fit(x_train, y_train)

random_search.best_params_
random_search.best_score_
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:317: UserWarning: The total space of parameters 2 is smaller than n_iter=30. Running 2 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# np.float64(0.8552718025618239)

# %%
results = pd.DataFrame({
    "Model": [
        "Linear Regression",
        "Decision Tree",
        "Random Forest (Tuned)",
        "Gradient Boosting (Tuned)",
        "XGBoost (Tuned)"
    ],
    "MAE": [
        first_mae,
        des_mae,
        rf_mae,
        gb_mae,
        xgb_mae
    ],
    "RMSE": [
        first_rmse,
        des_rmse,
        rf_rmse,
        gb_rmse,
        xgb_rmse
    ],
    "R²": [
        first_r2,
        des_r2,
        rf_r2,
        gb_r2,
        xgb_r2
    ]
})

results.sort_values("R²", ascending=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[62], line 10
#       1 results = pd.DataFrame({
#       2     "Model": [
#       3         "Linear Regression",
#       4         "Decision Tree",
#       5         "Random Forest (Tuned)",
#       6         "Gradient Boosting (Tuned)",
#       7         "XGBoost (Tuned)"
#       8     ],
#       9     "MAE": [
# ---> 10         first_mae,
#      11         des_mae,
#      12         rf_mae,
#      13         gb_mae,
#      14         xgb_mae
#      15     ],
#      16     "RMSE": [
#      17         first_rmse,
#      18         des_rmse,
#      19         rf_rmse,
#      20         gb_rmse,
#      21         xgb_rmse
#      22     ],
#      23     "R²": [
#      24         first_r2,
#      25         des_r2,
#      26         rf_r2,
#      27         gb_r2,
#      28         xgb_r2
#      29     ]
#      30 })
#      32 results.sort_values("R²", ascending=False)
#
# NameError: name 'first_mae' is not defined

# %%
import joblib

joblib.dump(rf_pipeline, "../models/profit_prediction_model.pkl")
# Out:
# ['../models/profit_prediction_model.pkl']

# %% [markdown]
# *** Note: Having evaluated Linear Regression, Random Forest, and Gradient Boosting and performed hyperparameter tuning using RandomizedSearchCV. The default Random Forest achieved the best performance (R² = 0.872), so it was selected as the final model ***
